# %%
# change the function parameters if you need 
def test(str1, str2):
  # write your code below this line 
    x = str(str1)   
    y = str(str2) 
    
    result = x[0:3] + y[0:3]   

    return  result # write here the returned value of the function  
  # Write your code above this line
    

    
test("Coding","World")
# Out:
# 'CodWor'

# %%
#PYTHON BASICS : QUESTION 1

def reverse_slicing(s):
    return s[::-1]

lname_fname = "Mamadou Saliou Diallo"

if __name__ == "__main__":
    print("Reverse lnamefname is =", reverse_slicing(lname_fname))
# Out:
# Reverse lnamefname is = ollaiD uoilaS uodamaM

# %%
#PYTHON BASICS : QUESTION 2

n = int(input("Input an integer : "))
a1 = int( "%s" % n )
a2 = int( "%s%s" % (n,n) )
a3 = int( "%s%s%s" % (n,n,n) )
print (a1+a2+a3)
# Out:
# Input an integer : 5
# 615

# %%
#PYTHON BASICS : QUESTION 3

n = int(input("n : "))
if n % 2 == 0:
    print("Number is EVEN")
else:
    print("Number is ODD")
# Out:
# n : 5
# Number is ODD

# %%
#PYTHON BASICS : QUESTION 4

N=2000
for i in range(2000,3200):
    N = (N+7) / 7
    print(N)
# Out:
# 286.7142857142857
# 41.95918367346939
# 6.994169096209913
# 1.9991670137442732
# 1.2855952876777532
# 1.1836564696682503
# 1.1690937813811786
# 1.1670133973401684
# 1.1667161996200242
# 1.1666737428028606
# 1.1666676775432658
# 1.1666668110776095
# 1.1666666872968015
# 1.1666666696138288
# 1.1666666670876897
# 1.1666666667268129
# 1.166666666675259
# 1.166666666667894
# 1.166666666666842
# 1.1666666666666916
# 1.16666666666667
# 1.1666666666666672
# 1.1666666666666667
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# 1.1666666666666665
# ...

# %%
#PYTHON BASICS : QUESTION 5

import math
n = int(input("n = " ))
nfactorial = math.factorial(n)
print(nfactorial)
# Out:
# n = 8
# 40320

# %%
#PYTHON BASICS : QUESTION 6

string = "helloteam"
print(string.replace('el', ''))
# Out:
# hloteam

# %%
#PYTHON BASICS : QUESTION 7

price = int(input("Price : "))
if price<200:
    discount = 0.1 * price
    print("Discount is : ", discount)
elif price>= 200 and price<500:
    discount = 0.1*200 + (price-200)*0.3
    print("Discount is : ", discount)
else:
    discount = 0.1*200 + 0.3*200 + (price-500)*0.5
    print("Discount is : ", discount)
# Out:
# Price : 200
# Discount is :  20.0
